# %%
# Import Dependencies and Yahoo Finance API for historical stock data
# !pip install yfinance

import yfinance as yf
import os
import json
import pandas as pd

# %% [markdown]
# ## Creating Multiple Ticker Data Frame

# %%
ipo_info_df = pd.read_csv("ipo_info.csv")
ipo_info_df
# Out:
#    ticker       date                                       company name  \
# 0     CLW   5-Dec-08                       Clearwater Paper Corporation
# 1    LOPE  20-Nov-08                        Grand Canyon Education Inc.
# 2     MHH  19-Nov-08                                Mastech Digital Inc
# 3     EBR  19-Nov-08  Centrais Electricas Brasileiras S A American D...
# 4    XTLB  18-Nov-08                        XTL Biopharmaceuticals Ltd.
# ..    ...        ...                                                ...
# 61    BIP  10-Jan-08  Brookfield Infrastructure Partners LP Limited ...
# 62   SFBC   9-Jan-08                       Sound Financial Bancorp Inc.
# 63   SATS   2-Jan-08                               EchoStar Corporation
# 64   FLNT   2-Jan-08                                        Fluent Inc.
# 65    DAN   2-Jan-08                                  Dana Incorporated
#
#                             industry              sector  \
# ...

# %%
ticker_list = ipo_info_df['ticker'].unique()
print(ticker_list)
# Out:
# ['CLW' 'LOPE' 'MHH' 'EBR' 'XTLB' 'DFFN' 'DMRC' 'HBCP' 'FSFG' 'EC' 'HCI'
#  'CPHC' 'IBIO' 'WPRT' 'GSL' 'MYRG' 'TREE' 'PRIM' 'DL' 'URG' 'JBT' 'EVK'
#  'ERII' 'FTFT' 'BTG' 'ALO' 'CDXC' 'CRHM' 'HPJ' 'OCSL' 'BKJ' 'SB' 'HMTA'
#  'SINO' 'MLVF' 'AGNC' 'CFX' 'KDP' 'MHLD' 'AWK' 'IPI' 'CGA' 'SGOC' 'HGSH'
#  'HI' 'IRDM' 'V' 'BEAT' 'PM' 'SLS' 'HCCI' 'GLBS' 'BPTH' 'SRCI' 'CBPO'
#  'SHIP' 'SOL' 'MOFG' 'ISDR' 'EBSB' 'IDEX' 'BIP' 'SFBC' 'SATS' 'FLNT' 'DAN']

# %%
# !pip install pandas-datareader
import pandas_datareader as pdr
import datetime
# Out:
# ...
#      |████████████████████████████████| 109 kB 1.8 MB/s eta 0:00:01
# ...

# %%
results = {}
def ticker_data():
    try:
        for ticker in ticker_list:
            results[ticker] = pdr.get_data_yahoo(ticker, start="2017-01-01", end="2017-01-31")
    except: 
        pass
    print(results)
    #df = pd.DataFrame(data=results,index=[0]).set_index()
    #df
    
ticker_data=ticker_data()
ticker_data
# Out:
# {'CLW':                  High        Low       Open      Close  Volume  Adj Close
# Date
# 2017-01-03  67.449997  65.849998  66.300003  66.550003   44900  66.550003
# 2017-01-04  67.400002  65.500000  66.750000  66.849998   80100  66.849998
# 2017-01-05  67.099998  65.750000  66.599998  65.800003   35800  65.800003
# 2017-01-06  65.199997  62.349998  65.199997  62.599998   87000  62.599998
# 2017-01-09  62.950001  61.500000  62.400002  61.650002   55400  61.650002
# 2017-01-10  63.150002  61.299999  61.549999  63.049999   38400  63.049999
# 2017-01-11  64.000000  62.349998  63.049999  63.849998   53800  63.849998
# 2017-01-12  63.599998  61.200001  63.599998  62.250000   42600  62.250000
# 2017-01-13  63.450001  62.200001  62.200001  62.900002   36200  62.900002
# 2017-01-17  62.459999  61.250000  62.400002  61.650002   37800  61.650002
# 2017-01-18  61.900002  61.009998  61.900002  61.750000   33000  61.750000
# ...

# %%
results = {}
def ticker_data():
    try:
        for ticker in ticker_list:
            results[ticker] = pdr.get_data_yahoo(ticker, start="2017-01-01", end="2017-01-31")
    except: 
        pass
    print(results)
    #df = pd.DataFrame(data=results,index=[0]).set_index()
    #df
    
ticker_data=ticker_data()
ticker_data
# Out:
# []

# %%
results=ticker_data.unstack()
results
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /var/folders/62/br05s5jx4psbv26qjm7326rw0000gn/T/ipykernel_86191/4145042708.py in <module>
# ----> 1 results=ticker_data.unstack()
#       2 results
#
# AttributeError: 'NoneType' object has no attribute 'unstack'

# %%
pd.DataFrame.from_dict(results,orient="index").T
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/62/br05s5jx4psbv26qjm7326rw0000gn/T/ipykernel_86191/3995165599.py in <module>
# ----> 1 pd.DataFrame.from_dict(results,orient="index").T
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/frame.py in from_dict(cls, data, orient, dtype, columns)
#    1591             raise ValueError("only recognize index or columns for orient")
#    1592
# -> 1593         return cls(data, index=index, columns=columns, dtype=dtype)
#    1594
#    1595     def to_numpy(
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/frame.py in __init__(self, data, index, columns, dtype, copy)
#     709                     )
#     710                 else:
# --> 711                     mgr = ndarray_to_mgr(
#     712                         data,
#     713                         index,
#
# ...

# %% [markdown]
# ## Testing 1 Ticker

# %%
msft = yf.Ticker("MSFT")
msft_hist = msft.history(period="max")

# %%
#Display tthe data
msft_hist.head(10)
# Out:
#                 Open      High       Low     Close      Volume  Dividends  \
# Date
# 1986-03-13  0.055654  0.063838  0.055654  0.061109  1031788800        0.0
# 1986-03-14  0.061109  0.064384  0.061109  0.063292   308160000        0.0
# 1986-03-17  0.063292  0.064929  0.063292  0.064383   133171200        0.0
# 1986-03-18  0.064384  0.064929  0.062201  0.062746    67766400        0.0
# 1986-03-19  0.062746  0.063292  0.061109  0.061655    47894400        0.0
# 1986-03-20  0.061655  0.061655  0.059473  0.060018    58435200        0.0
# 1986-03-21  0.060018  0.061109  0.057290  0.058381    59990400        0.0
# 1986-03-24  0.058381  0.058381  0.056199  0.056745    65289600        0.0
# 1986-03-25  0.056745  0.057836  0.056199  0.057836    32083200        0.0
# 1986-03-26  0.057836  0.060018  0.057290  0.059473    22752000        0.0
#
#             Stock Splits
# Date
# 1986-03-13           0.0
# 1986-03-14           0.0
# 1986-03-17           0.0
# 1986-03-18           0.0
# ...

# %%
# Visualize microsoft stock prices
msft_hist.plot.line(y="Close", use_index=True)
# Out:
# <AxesSubplot:xlabel='Date'>

# %% [markdown]
# # Prep the data

# %%
# Confirm the actual closing price
data = msft_hist[["Close"]]
data = data.rename(columns = {'Close':'Actual_Close'})

# Setup our target.  This identifies if the price went up or down
data["Target"] = msft_hist.rolling(2).apply(lambda x: x.iloc[1] > x.iloc[0])["Close"]

# %%
# Shift stock prices forward one day, so we're predicting tomorrow's stock prices from today's prices.
#This is done to avoid leakage in tthe model predicting future priced with future data
msft_prev = msft_hist.copy()
msft_prev = msft_prev.shift(1)

# %%
# Create our training data
predictors = ["Close", "Volume", "Open", "High", "Low"]
data = data.join(msft_prev[predictors]).iloc[1:]
data.head(5)
# Out:
#             Actual_Close  Target     Close        Volume      Open      High  \
# Date
# 1986-03-14      0.063292     1.0  0.061109  1.031789e+09  0.055654  0.063838
# 1986-03-17      0.064383     1.0  0.063292  3.081600e+08  0.061109  0.064384
# 1986-03-18      0.062746     0.0  0.064383  1.331712e+08  0.063292  0.064929
# 1986-03-19      0.061655     0.0  0.062746  6.776640e+07  0.064384  0.064929
# 1986-03-20      0.060018     0.0  0.061655  4.789440e+07  0.062746  0.063292
#
#                  Low
# Date
# 1986-03-14  0.055654
# 1986-03-17  0.061109
# 1986-03-18  0.063292
# 1986-03-19  0.062201
# 1986-03-20  0.061109

# %% [markdown]
# # Creating a machine learning model

# %%
from sklearn.ensemble import RandomForestClassifier
import numpy as np

# Create a random forest classification model.  Set min_samples_split high to ensure we don't overfit.
model = RandomForestClassifier(n_estimators=100, min_samples_split=200, random_state=1)

# Create a train and test set
train = data.iloc[:-100]
test = data.iloc[-100:]

model.fit(train[predictors], train["Target"])
# Out:
# RandomForestClassifier(min_samples_split=200, random_state=1)

# %%
from sklearn.metrics import precision_score

# Evaluate error of predictions
preds = model.predict(test[predictors])
preds = pd.Series(preds, index=test.index)
precision_score(test["Target"], preds)
# Out:
# 0.44565217391304346

# %%
combined = pd.concat({"Target": test["Target"],"Predictions": preds}, axis=1)
combined.plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %% [markdown]
# # BACKTESTING

# %%
def backtest(data, model, predictors, start=1000, step=750):
    predictions = []
    # Loop over the dataset in increments
    for i in range(start, data.shape[0], step):
        # Split into train and test sets
        train = data.iloc[0:i].copy()
        test = data.iloc[i:(i+step)].copy()
        
        # Fit the random forest model
        model.fit(train[predictors], train["Target"])
        
        # Make predictions
        preds = model.predict_proba(test[predictors])[:,1]
        preds = pd.Series(preds, index=test.index)
        preds[preds > .6] = 1
        preds[preds<=.6] = 0
        
        # Combine predictions and test values
        combined = pd.concat({"Target": test["Target"],"Predictions": preds}, axis=1)
        
        predictions.append(combined)
    
    return pd.concat(predictions)

# %%
predictions = backtest(data, model, predictors)

# %%
predictions["Predictions"].value_counts()
# Out:
# 0.0    7417
# 1.0     739
# Name: Predictions, dtype: int64

# %%
precision_score(predictions["Target"], predictions["Predictions"])
# Out:
# 0.5047361299052774

# %% [markdown]
# # Improving accuracy

# %%
weekly_mean = data.rolling(7).mean()
quarterly_mean = data.rolling(90).mean()
annual_mean = data.rolling(365).mean()
weekly_trend = data.shift(1).rolling(7).mean()["Target"]

# %%
data["weekly_mean"] = weekly_mean["Close"] / data["Close"]
data["quarterly_mean"] = quarterly_mean["Close"] / data["Close"]
data["annual_mean"] = annual_mean["Close"] / data["Close"]

data["annual_weekly_mean"] = data["annual_mean"] / data["weekly_mean"]
data["annual_quarterly_mean"] = data["annual_mean"] / data["quarterly_mean"]
data["weekly_trend"] = weekly_trend

data["open_close_ratio"] = data["Open"] / data["Close"]
data["high_close_ratio"] = data["High"] / data["Close"]
data["low_close_ratio"] = data["Low"] / data["Close"]

# %%
full_predictors = predictors + ["weekly_mean", "quarterly_mean", "annual_mean", "annual_weekly_mean", "annual_quarterly_mean", "open_close_ratio", "high_close_ratio", "low_close_ratio", "weekly_trend"]
predictions = backtest(data.iloc[365:], model, full_predictors)

# %%
precision_score(predictions["Target"], predictions["Predictions"])
# Out:
# 0.5779816513761468

# %%
# Show how many trades we would make

predictions["Predictions"].value_counts()
# Out:
# 0.0    7573
# 1.0     218
# Name: Predictions, dtype: int64

# %%
predictions.iloc[-100:].plot()
# Out:
# <AxesSubplot:xlabel='Date'>
