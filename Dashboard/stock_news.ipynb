# %%
import requests
import json
api_key = "pwru2cb88ddc9z4yqy0c3seppd5oainjsefr3aub"

# %%
url = "https://stocknewsapi.com/api/v1?tickers=tsla&items=50&page=1&token="+ api_key
response = requests.get(url).json()
response
# Out:
# {'data': [{'news_url': 'https://investorplace.com/2022/07/tsla-stock-news-5-biggest-headlines-that-tesla-investors-need-to-know-this-week-7/',
#    'image_url': 'https://cdn.snapi.dev/images/v1/u/x/tsla1600e-1477513.jpg',
#    'title': 'TSLA Stock News: 5 Biggest Headlines That Tesla Investors Need to Know This Week',
#    'text': "Source: Shutterstock Tesla's (NASDAQ: TSLA ) winning streak has continued this week, with the electric vehicle (EV) leader boosted by multiple growth catalysts. For one, a sweeping climate bill including EV tax credits moved forward in the U.S. Senate yesterday.",
#    'source_name': 'InvestorPlace',
#    'date': 'Fri, 29 Jul 2022 12:51:45 -0400',
#    'topics': [],
#    'sentiment': 'Positive',
#    'type': 'Article',
#    'tickers': ['TSLA']},
#   {'news_url': 'https://www.fool.com/investing/2022/07/29/why-tesla-shares-moved-higher-today/',
#    'image_url': 'https://cdn.snapi.dev/images/v1/y/y/wdw2233-1477485.jpg',
# ...

# %%
response['data']
# Out:
# [{'news_url': 'https://investorplace.com/2022/07/tsla-stock-news-5-biggest-headlines-that-tesla-investors-need-to-know-this-week-7/',
#   'image_url': 'https://cdn.snapi.dev/images/v1/u/x/tsla1600e-1477513.jpg',
#   'title': 'TSLA Stock News: 5 Biggest Headlines That Tesla Investors Need to Know This Week',
#   'text': "Source: Shutterstock Tesla's (NASDAQ: TSLA ) winning streak has continued this week, with the electric vehicle (EV) leader boosted by multiple growth catalysts. For one, a sweeping climate bill including EV tax credits moved forward in the U.S. Senate yesterday.",
#   'source_name': 'InvestorPlace',
#   'date': 'Fri, 29 Jul 2022 12:51:45 -0400',
#   'topics': [],
#   'sentiment': 'Positive',
#   'type': 'Article',
#   'tickers': ['TSLA']},
#  {'news_url': 'https://www.fool.com/investing/2022/07/29/why-tesla-shares-moved-higher-today/',
#   'image_url': 'https://cdn.snapi.dev/images/v1/y/y/wdw2233-1477485.jpg',
#   'title': 'Why Tesla Shares Moved Higher Today',
# ...

# %%
for article in response['data']: 
    print(article['title'])
# Out:
# TSLA Stock News: 5 Biggest Headlines That Tesla Investors Need to Know This Week
# Why Tesla Shares Moved Higher Today
# 5 Reasons ‘Cathie Wood Stocks' Could Double Over the Next 12 Months
# Tesla and other EV buyers could soon be eligible for $7,500 federal tax credits under senate deal
# Why I Sold Most of My Tesla Stock Last Week
# Tesla, GM buyers would get EV tax credits again under Dems' climate bill
# Senate expands tax credit for EV drivers
# Kimbal Musk Just Doubled Down on Tesla (TSLA) Stock
# EV Tax Credits Will Send TSLA Stock Soaring
# Tesla: Most Shorted Doesn't Mean Much
# Why Tesla, Nikola, and Lordstown Motors Stocks Are Rising Today
# Tesla (TSLA) is Europe's most-Googled stock, study finds
# 5 Monster Growth Stocks Begging to Be Bought
# Feds probe Tesla crash that killed motorcyclist in Utah
# 3 Top Growth Stocks I'd Buy Right Now Without Any Hesitation
# Tesla Stock (TSLA) Rally Hits Selling Resistance Zone
# ...
